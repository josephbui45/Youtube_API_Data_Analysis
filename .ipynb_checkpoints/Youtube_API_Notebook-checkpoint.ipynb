# %%
from googleapiclient.discovery import build
from dateutil import parser
import pandas as pd
from IPython.display import JSON
import isodate

#Data Visualization
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns
sns.set(style="darkgrid", color_codes=True)

# NLP
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
nltk.download('punkt')
from wordcloud import WordCloud
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\josep\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\josep\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
api_key = 'AIzaSyAjbVKruMJqShrZ_DYPzAegxj7JLjH5xKU'

# %%
channel_ids = [#'UCoOae5nYA7VqaXzerajD0lg',
               'UC4PooiX37Pld1T8J5SYT-SQ'
              # more channels here
              ]

# %%
api_service_name = "youtube"
api_version = "v3"

# Get credentials and create an API client
youtube = build(api_service_name, api_version, developerKey = api_key)

# %%
def get_channel_stats(youtube, channel_ids):
    all_data = []
    request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id=','.join(channel_ids)
    )
    response = request.execute()
    #loop through items
    for i in range(len(response['items'])):
            data = dict(channelName = response['items'][i]['snippet']['title'],
                    subscribers = response['items'][i]['statistics']['subscriberCount'],
                    views = response['items'][i]['statistics']['viewCount'],
                    totalVideos = response['items'][i]['statistics']['videoCount'],
                    playlistId = response['items'][i]['contentDetails']['relatedPlaylists']['uploads'])
            all_data.append(data)
    
    return pd.DataFrame(all_data)

# %%
def get_video_ids(youtube, playlist_id):
    video_ids = []
    
    request = youtube.playlistItems().list(
        part="snippet,contentDetails",
        playlistId=playlist_id,
        
        maxResults = 50
    )
    response = request.execute()
    
    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])
            
    next_page_token = response.get('nextPageToken')
    another_page = True
    while another_page:
        if next_page_token is None:
            another_page = False
        else:
            request = youtube.playlistItems().list(
                part="snippet,contentDetails",
                playlistId=playlist_id,
                maxResults = 50,
                pageToken = next_page_token)
            response = request.execute()
        
            for i in range(len(response['items'])):
                video_ids.append(response['items'][i]['contentDetails']['videoId'])
            
            next_page_token = response.get('nextPageToken')
        
    return video_ids

# %%
def get_video_details(youtube, video_ids):
    all_video_info = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
            part="snippet, contentDetails, statistics",
            id =','.join(video_ids[i:i+50])
        )
        response = request.execute()

        for video in response['items']:
            stats_to_keep = {'snippet': ['channelTitle', 'title', 'description', 'tags', 'publishedAt'],
                             'statistics': ['viewCount', 'likeCount', 'favouriteCount', 'commentCount'],
                             'contentDetails': ['duration', 'definition', 'caption']
                            }
            video_info = {}
            video_info['video_id'] = video['id']

            for x in stats_to_keep.keys():
                for y in stats_to_keep[x]:
                    try:
                        video_info[y] = video[x][y]
                    except:
                        video_info[y] = None

            all_video_info.append(video_info)
        
    return pd.DataFrame(all_video_info)

# %%
def get_comments_in_videos(youtube, video_ids):
    all_comments = []
    
    for video_id in video_ids:
        try:   
            request = youtube.commentThreads().list(
                part="snippet,replies",
                videoId=video_id
            )
            response = request.execute()
        
            comments_in_video = [comment['snippet']['topLevelComment']['snippet']['textOriginal'] for comment in response['items'][0:10]]
            comments_in_video_info = {'video_id': video_id, 'comments': comments_in_video}

            all_comments.append(comments_in_video_info)
            
        except: 
            # When error occurs - most likely because comments are disabled on a video
            print('Could not get comments for video ' + video_id)
        
    return pd.DataFrame(all_comments)

# %% [markdown]
# ### Get Channel Statistics

# %%
channel_data = get_channel_stats(youtube, channel_ids)
channel_data
# Out:
#              channelName subscribers       views totalVideos  \
# 0  Good Mythical Morning    17700000  8090457901        2985
#
#                  playlistId
# 0  UU4PooiX37Pld1T8J5SYT-SQ

# %%
for c in channel_data['channelName'].unique():
    print("Getting video information from channel: " + c)
    playlist_id = channel_data.loc[channel_data['channelName']== c, 'playlistId'].iloc[0]
    video_ids = get_video_ids(youtube, playlist_id)
    
video_returned_details = get_video_details(youtube, video_ids)
video_returned_details
# Out:
# Getting video information from channel: Good Mythical Morning
#          video_id           channelTitle  \
# 0     bAUJwz21Zwk  Good Mythical Morning
# 1     LJY0oV3SZUY  Good Mythical Morning
# 2     Sj_Qib1PP7U  Good Mythical Morning
# 3     Mh96IaYXaU0  Good Mythical Morning
# 4     dT-pZhKkU_c  Good Mythical Morning
# ...           ...                    ...
# 2980  1J6Ty0vPFNQ  Good Mythical Morning
# 2981  FGw6m-g5wl8  Good Mythical Morning
# 2982  _KEnkcZQ3uE  Good Mythical Morning
# 2983  TTLM2CrQKQU  Good Mythical Morning
# 2984  6yw2NPHPUys  Good Mythical Morning
#
#                                      title  \
# 0       Reacting To Crazy Smart Home Hacks
# 1        Will It Chips & Salsa? Taste Test
# 2             We Put Furby In A Guillotine
# 3     Match The Flavor To The Oreos (Game)
# 4             Blind Draw My Face Challenge
# ...                                    ...
# 2980   AMAZING SUPERNOTE from joejumps4fun
# 2981        Edbassmaster on SuperNote Live
# ...

# %% [markdown]
# ## Data Pre-Processing

# %%
video_returned_details.isnull().any()
# Out:
# video_id          False
# channelTitle      False
# title             False
# description       False
# tags               True
# publishedAt       False
# viewCount          True
# likeCount          True
# favouriteCount     True
# commentCount       True
# duration          False
# definition        False
# caption           False
# dtype: bool

# %%
video_returned_details.dtypes
# Out:
# video_id          object
# channelTitle      object
# title             object
# description       object
# tags              object
# publishedAt       object
# viewCount         object
# likeCount         object
# favouriteCount    object
# commentCount      object
# duration          object
# definition        object
# caption           object
# dtype: object

# %%
numeric_cols = ['viewCount', 'likeCount', 'favouriteCount', 'commentCount']
video_returned_details[numeric_cols] = video_returned_details[numeric_cols].apply(pd.to_numeric, errors = 'coerce', axis = 1)

# %%
#Publish day in the week
video_returned_details['publishedAt'] = video_returned_details['publishedAt'].apply(lambda x: parser.parse(x))
video_returned_details['publishDayName'] = video_returned_details['publishedAt'].apply(lambda x: x.strftime("%A"))

# %%
video_returned_details['durationSecs'] = video_returned_details['duration'].apply(lambda x: isodate.parse_duration(x))
video_returned_details['durationSecs'] = video_returned_details['durationSecs'].astype('timedelta64[s]')

# %%
video_returned_details[['durationSecs', 'duration']]
# Out:
#       durationSecs  duration
# 0           1341.0  PT22M21S
# 1           1145.0   PT19M5S
# 2             54.0     PT54S
# 3            907.0   PT15M7S
# 4           1439.0  PT23M59S
# ...            ...       ...
# 2980         600.0     PT10M
# 2981         600.0     PT10M
# 2982         600.0     PT10M
# 2983         600.0     PT10M
# 2984          48.0     PT48S
#
# [2985 rows x 2 columns]

# %%
# Add tag count to table
video_returned_details['tagCount'] = video_returned_details['tags'].apply(lambda x: 0 if x is None else len(x))

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Best Performing Videos

# %%
ax = sns.barplot(x = 'title', y = 'viewCount', data = video_returned_details.sort_values('viewCount', ascending=False)[0:9])
plot = ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos:'{:,.0f}'.format(x/1000) + 'K'))

# %% [markdown]
# ### Worst Performing Videos

# %%
ax = sns.barplot(x = 'title', y = 'viewCount', data = video_returned_details.sort_values('viewCount', ascending=True)[0:9])
plot = ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos:'{:,.0f}'.format(x/1000) + 'K'))

# %% [markdown]
# ### View Distribution per Video

# %%
sns.violinplot(video_returned_details['channelTitle'], video_returned_details['viewCount'])
# Out:
# C:\Users\josep\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='channelTitle', ylabel='viewCount'>

# %% [markdown]
# ### Views vs Likes and Comments

# %%
fig, ax = plt.subplots(1,2)
sns.scatterplot(data = video_returned_details, x = 'commentCount', y = 'viewCount', ax = ax[0])
sns.scatterplot(data = video_returned_details, x = 'likeCount', y = 'viewCount', ax = ax[1])
# Out:
# <AxesSubplot:xlabel='likeCount', ylabel='viewCount'>

# %% [markdown]
# ### Video Duration

# %%
sns.histplot(data = video_returned_details, x = 'durationSecs', bins=30)
# Out:
# <AxesSubplot:xlabel='durationSecs', ylabel='Count'>

# %% [markdown]
# ### WordClud for Video Titles

# %%
stop_words = set(stopwords.words('english'))
video_returned_details['title_no_stopwords'] = video_returned_details['title'].apply(lambda x: [item for item in str(x).split() if item not in stop_words])

all_words = list([a for b in video_returned_details['title_no_stopwords'].tolist() for a in b])
all_words_str = ' '.join(all_words) 

def plot_cloud(wordcloud):
    plt.figure(figsize=(30, 20))
    plt.imshow(wordcloud) 
    plt.axis("off");

wordcloud = WordCloud(width = 2000, height = 1000, random_state=1, background_color='black', 
                      colormap='viridis', collocations=False).generate(all_words_str)
plot_cloud(wordcloud)

# %% [markdown]
# ### Upload Schedule

# %%
day_df = pd.DataFrame(video_returned_details['publishDayName'].value_counts())
weekdays = [ 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
day_df = day_df.reindex(weekdays)
ax = day_df.reset_index().plot.bar(x='index', y='publishDayName', rot=0)
